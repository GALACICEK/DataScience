# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Helpful does:
# - What is API, REST,RESTFULL
# - What is request, response and keys
#
# - https://github.com/public-apis/public-apis
# - https://dev.socrata.com/consumers/getting-started.html
# - API key : https://console.cloud.google.com/
# - https://blog.streamlit.io/8-tips-for-securely-using-api-keys/
# - Find youtube Channel Id : https://www.streamweasels.com/tools/youtube-channel-id-and-user-id-convertor/
#
# - https://developers.google.com/youtube/v3/docs?hl=tr
#
# - https://help.openai.com/en/articles/5112595-best-practices-for-api-key-safety
# - https://blog.streamlit.io/8-tips-for-securely-using-api-keys/

# %%
#source https://data.colorado.gov
# url_api_endpoint = "https://data.colorado.gov/resource/tv8u-hswn.json"
url="https://data.colorado.gov/resource/tv8u-hswn.json?$where=age between 20 and 25 and year between 2020 and 2025&county=Boulder&$select=year,age,femalepopulation"

# %%
url = url.replace(" ","%20")

# %%
data = pd.read_json(url)

# %%
data
# Out:
#     year  age  femalepopulation
# 0   2022   22              3296
# 1   2020   20              3830
# 2   2020   21              3647
# 3   2021   24              2194
# 4   2023   23              2716
# 5   2023   21              3778
# 6   2025   22              3486
# 7   2025   25              2329
# 8   2020   22              3290
# 9   2022   21              3647
# 10  2020   25              2173
# 11  2022   24              2314
# 12  2023   25              2318
# 13  2021   25              2244
# 14  2024   22              3367
# 15  2020   23              2610
# 16  2024   21              3890
# 17  2022   23              2645
# 18  2023   22              3242
# 19  2024   23              2658
# 20  2025   21              3779
# 21  2022   20              3881
# 22  2022   25              2224
# 23  2025   24              2271
# 24  2024   24              2324
# 25  2023   20              3999
# 26  2025   23              2789
# 27  2023   24              2258
# 28  2021   20              3732
# 29  2021   22              3201
# 30  2020   24              2268
# 31  2025   20              3806
# 32  2024   20              3881
# 33  2024   25              2257
# 34  2021   23              2677
# 35  2021   21              3681

# %%
import requests
from config import YOUTUBE_API_KEY
import time

# %%
CHANNEL_ID ="UCeT3Ep2sgFiy0B5N1gX5N4Q"
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyDDJXuJb1f88YbhBQl5hv6IleuVEhjd_oE&channelId=UCeT3Ep2sgFiy0B5N1gX5N4Q&part=snippet,id&order=date&maxResults=1000

# %%
response = requests.get(url).json()
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'hGghBn5NqJuxfvJfzKvwHZvDZLg',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'TR',
#  'pageInfo': {'totalResults': 730, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'ldfRWEpSYHZazSFRMLOzuwv_Bjg',
#    'id': {'kind': 'youtube#video', 'videoId': 'DUI04XwQo4A'},
#    'snippet': {'publishedAt': '2023-12-16T15:00:10Z',
#     'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#     'title': 'BU KİTAP BENİ DELİRTTİ! | Gökçen - Loressima Kitap Yorumu',
#     'description': 'Kitabı İncelemek ve Satın Almak İçin: https://www.ephesusdukkan.com/gokcen-1-unutulan-cicekler-ciltli Bana Ulaşmak İçin: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/
...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HqA8fBieOPs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HqA8fBieOPs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HqA8fBieOPs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sıla Özkan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-13T16:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fV_Nc-wIndfsEkeHdX8bEFnhHHM',
#    'id': {'kind': 'youtube#video', 'videoId': 'hapjfflTMRo'},
#    'snippet': {'publishedAt': '2023-01-06T15:00:21Z',
#     'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#     'title': 'Unutulmuş Kuşlar Göğü - K. Kübra Berk | OKUMALISIN!',
#     'description': 'Kitabı İncelemek veya Satın Almak İçin: https://www.ephesusdukkan.com/unutulmus-kuslar-gogu-1-ciltli-imzali Bana Ulaşmak İçin: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hapjfflTMRo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hapjfflTMRo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hapjfflTMRo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sıla Özkan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-06T15:00:21Z'}}]}

# %%
response["items"][0]['id']['videoId']
# Out:
# 'DUI04XwQo4A'

# %%
response["items"][0]['snippet']['title']
# Out:
# 'BU KİTAP BENİ DELİRTTİ! | Gökçen - Loressima Kitap Yorumu'

# %%
response["items"][0]['snippet']['description']
# Out:
# 'Kitabı İncelemek ve Satın Almak İçin: https://www.ephesusdukkan.com/gokcen-1-unutulan-cicekler-ciltli Bana Ulaşmak İçin: ...'

# %%
response["items"][0]['snippet']['publishedAt']
# Out:
# '2023-12-16T15:00:10Z'

# %%
video_title = response["items"][0]['snippet']['title']
video_id = response["items"][0]['id']['videoId']
video_description = response["items"][0]['snippet']['description']

upload_time= response["items"][0]['snippet']['publishedAt']
upload_time = str(upload_time).split("T")[0]

print(video_title)
print(video_id)
print(video_description)
print(upload_time)
# Out:
# BU KİTAP BENİ DELİRTTİ! | Gökçen - Loressima Kitap Yorumu
# DUI04XwQo4A
# Kitabı İncelemek ve Satın Almak İçin: https://www.ephesusdukkan.com/gokcen-1-unutulan-cicekler-ciltli Bana Ulaşmak İçin: ...
# 2023-12-16

# %%
# for loop in response
for video in response["items"]:
    if video['id']['kind'] == "youtube#video":
        video_title = video['snippet']['title']
        print(video_title)
# Out:
# BU KİTAP BENİ DELİRTTİ! | Gökçen - Loressima Kitap Yorumu
# Kasım Ayında Okuduklarım, 2023 | 15 KİTAP!
# Artık Kitapları Sadece ZENGİNLER Okuyabiliyor
# 2 AYLIK BİTENLER | Ekim &amp; Kasım Ayında Bitenler 💄💓
# Kitaplık Turu, 2023 | Kitaplığımda Hangi Kitaplar Var?
# Project Pan 11. Güncelleme | KASIM 2023 💄🫶
# Project Pan 10. Güncelleme | EKİM 2023 💄🫶
# TÜM EVİMDE Sadeleşmeye Gidiyoruz! | Declutter 2023
# BU HİKAYE NASIL SONRA ERDİ? | Yabancı Elyel - Öznur Yıldırım  Övdüm mü Gömdüm mü?
# Project Pan 8. Güncelleme | AĞUSTOS  2023 💄🫶
# Temmuz Ayında Okuduklarım 2023 📚💓
# Maktule Borç 1 - Askıda Dehşet - Ömer Enes Çatalbaş  | Kitap Yorumu
# Project Pan 7. Güncelleme | TEMMUZ 2023 💄🫶
# BU KİTABI SEVECEKSİNİZ. | Havass - Ayhan Özden | Kitap Yorumu
# Project Pan 6. Güncelleme | HAZİRAN 2023 💄🫶
# BEN ARTIK YORULDUM! | Kar Küresi -  Beyza Alkoç | Övdüm mü Gömdüm mü?
# BU BİLGİLERİ TÜRKİYE&#39;DE İLK KEZ OKUYACAKSINIZ! | Çırak -Ayhan Özden
# 120 SAYFAYA BİR ÖMÜR SIĞDIRMAK | Perşembe&#39;yi Beklerken - Tolga Kayır
# DEX Kitap Kargosunu Açıyoruz!  + Çekiliş 💓📚
# Kidega’dan 350₺lik Kitap Alışverişi Yaptım 📚🤍
# Project Pan 5. Güncelleme | MAYIS 2023 💄🫶
# Ben Kişisel Gelişim Okuyorum... BEN!?
# Benimle Bir Gün 🎬💅🤍
# Zengin Koca Bulma Sanatı - Ayhan Özden | Övdüm mü, Gömdüm mü?
# November&#39;ı Avlamak - Adriana Mathers | Kitap Yorumu
# DAHA ÖNCE HİÇ BÖYLE KİTAP OKUMAMIŞTIM! | Kuzgun Leşi - İlkim Baldan Kesgin | Kitap Yorumu
# AYIP ETTİN OLIVIA | Dokunulmazlar   J J Mcavoy Kitap Yorumu
# Project Pan 3. Güncelleme MART 2023
# 15 KİTAP! | Mart Ayında Okuduklarım 2023 📚💓
# Güz Esintisi 2 - Burçin Sarıdoğan | Kitap Yorumu 📚😢
# BU KİTAP BENİ TRAVMATİZE ETTİ! | Güz Esintisi 1 - Burçin Sarıdoğan | Kitap Yorumu
# Büyük Polisiye Kargosu ve ÇEKİLİŞ  | Gelen Kitap Kargolarını Açıyorum! 📚💓
# 400 SAYFAYI BİR GÜNDE OKUMAK! | Ötanazi Okulu 3 - Maral Atmaca
# Gelen Kitap Kargolarını Açıyorum! 💓📚
# Şubat Ayında Okuduklarım, 2023 | En İyi Polisiye Kitaplar, Romantik Gençlik Kitapları...
# Şubat Ayında Bitenler, 2023 | Gördüğüm en iyi uygun fiyatlı şampuan, imza parfümüm...
# Belladonna’ya Bir Sözüm Var!
# Pusula: Kolezyum - Kader Arvas | Kitap Yorumu
# Şubat Ayında Okuduklarım 📚🤍
# Çiçekler ve Yasemin Kitap Yorumu ve Depremle Alakalı Konuşmak İstedim
# Youna 2023 Ajandamı Nasıl Kullanıyorum? 💓📒
# Youna Ajandamı Nasıl Kullanıyorum? 🤍
# Ocak Ayında Okuduklarım, 2023
# Ocak Ayında Neler Okudum? 📚🤍
# Bitenler 2023, doğal roll on, yüz jileti, kırk yıllık far paleti
# Rota 2   Leman Veli  | Kitap Yorumu
# ARDEL 2: KAN GÜLLERİ  - Sinem Ataklı | OKUMALISIN!
# En Romantik Kore Dizileri, 2022
# BÖYLE BİR KİTAP OLABİLİR Mİ?! | Ateşpare 2 - Ceren Melek
# Unutulmuş Kuşlar Göğü - K. Kübra Berk | OKUMALISIN!

# %%
video_id='DUI04XwQo4A' # en son videonun idsi
video_ur_endpoint = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
video_response = requests.get(video_ur_endpoint).json()

# %%
video_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'sXoiBXTlNf1BibYTwczyYHhL9wg',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'tKp_7o4dzl20F5656HLiLbxMGfM',
#    'id': 'DUI04XwQo4A',
#    'statistics': {'viewCount': '2647',
#     'likeCount': '324',
#     'favoriteCount': '0',
#     'commentCount': '61'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
video_response['items'][0]['statistics']
# Out:
# {'viewCount': '2647',
#  'likeCount': '324',
#  'favoriteCount': '0',
#  'commentCount': '61'}

# %% [markdown]
# ### Creating workflow

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_time = video['snippet']['publishedAt']
        upload_date= str(upload_time).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()
        time.sleep(3)
        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        print(video_title)
        print(video_id)
        print(upload_date)
        print(f"view_count : {view_count}")
        print(f"like_count : {like_count}")
        print("\n")
# Out:
# BU KİTAP BENİ DELİRTTİ! | Gökçen - Loressima Kitap Yorumu
# DUI04XwQo4A
# 2023-12-16
# view_count : 2893
# like_count : 355
#
#
# Kasım Ayında Okuduklarım, 2023 | 15 KİTAP!
# Vfp43r47Dfs
# 2023-12-10
# view_count : 6461
# like_count : 464
#
#
# Artık Kitapları Sadece ZENGİNLER Okuyabiliyor
# AGldGeCzcww
# 2023-12-03
# view_count : 14047
# like_count : 1360
#
#
# 2 AYLIK BİTENLER | Ekim &amp; Kasım Ayında Bitenler 💄💓
# j6gBCnk1-D8
# 2023-11-25
# view_count : 4192
# like_count : 240
#
#
# Kitaplık Turu, 2023 | Kitaplığımda Hangi Kitaplar Var?
# uFySnEtrOt4
# 2023-11-19
# view_count : 9385
# like_count : 480
#
#
# Project Pan 11. Güncelleme | KASIM 2023 💄🫶
# 107jZVYTL3E
# 2023-11-12
# view_count : 5141
# like_count : 313
#
#
# Project Pan 10. Güncelleme | EKİM 2023 💄🫶
# jDR6hswFNZ0
# 2023-10-28
# view_count : 3496
# like_count : 228
#
#
# TÜM EVİMDE Sadeleşmeye Gidiyoruz! | Declutter 2023
# mTKqLtBjWDA
# 2023-10-21
# view_count : 5150
# like_count : 282
#
#
# BU HİKAYE NASIL SONRA ERDİ? | Yabancı Elyel - Öznur Yıldırım  Övdüm mü Gömdüm mü?
# s_-2UCqFuq4
# 2023-10-07
# view_count : 10100
# like_count : 557
#
#
# Project Pan 8. Güncelleme | AĞUSTOS  2023 💄🫶
# H0u3Fqg7_Oo
# 2023-09-03
# view_count : 3757
# like_count : 251
#
#
# Temmuz Ayında Okuduklarım 2023 📚💓
# YCxwn1dUp30
# 2023-08-20
# view_count : 4391
# like_count : 311
#
#
# Maktule Borç 1 - Askıda Dehşet - Ömer Enes Çatalbaş  | Kitap Yorumu
# _S6cV06AoJ0
# 2023-08-06
# view_count : 1091
# like_count : 106
#
#
# Project Pan 7. Güncelleme | TEMMUZ 2023 💄🫶
# iZI1UlZ68YQ
# 2023-07-30
# view_count : 4664
# like_count : 284
#
#
# BU KİTABI SEVECEKSİNİZ. | Havass - Ayhan Özden | Kitap Yorumu
# G8hdUuSGYoA
# 2023-07-23
# view_count : 1893
# like_count : 92
#
#
# Project Pan 6. Güncelleme | HAZİRAN 2023 💄🫶
# 8BW29aIKTgY
# 2023-07-09
# view_count : 4140
# like_count : 250
#
#
# BEN ARTIK YORULDUM! | Kar Küresi -  Beyza Alkoç | Övdüm mü Gömdüm mü?
# nE1S2Xp8mn8
# 2023-06-18
# view_count : 12856
# like_count : 592
#
#
# BU BİLGİLERİ TÜRKİYE&#39;DE İLK KEZ OKUYACAKSINIZ! | Çırak -Ayhan Özden
# 5RAOBGciIbc
# 2023-06-17
# view_count : 2034
# like_count : 130
#
#
# 120 SAYFAYA BİR ÖMÜR SIĞDIRMAK | Perşembe&#39;yi Beklerken - Tolga Kayır
# O2a2UzX6Jqo
# 2023-06-10
# view_count : 1463
# like_count : 143
#
#
# DEX Kitap Kargosunu Açıyoruz!  + Çekiliş 💓📚
# HpCsaR9xl3I
# 2023-06-03
# view_count : 9815
# like_count : 709
#
#
# Kidega’dan 350₺lik Kitap Alışverişi Yaptım 📚🤍
# d0OBljmxZqw
# 2023-05-31
# view_count : 49349
# like_count : 2422
#
#
# Project Pan 5. Güncelleme | MAYIS 2023 💄🫶
# FiTpzc_8WEA
# 2023-05-28
# view_count : 4879
# like_count : 267
#
#
# Ben Kişisel Gelişim Okuyorum... BEN!?
# 0UELIWue_mU
# 2023-05-27
# view_count : 1801
# like_count : 173
#
#
# Benimle Bir Gün 🎬💅🤍
# LNYF5SSkzrE
# 2023-05-24
# view_count : 7523
# like_count : 346
#
#
# Zengin Koca Bulma Sanatı - Ayhan Özden | Övdüm mü, Gömdüm mü?
# dFA1QLQx73Q
# 2023-05-21
# view_count : 5456
# like_count : 401
#
#
# November&#39;ı Avlamak - Adriana Mathers | Kitap Yorumu
# CfT8nEdrxAM
# 2023-05-20
# view_count : 2071
# like_count : 168
#
#
# DAHA ÖNCE HİÇ BÖYLE KİTAP OKUMAMIŞTIM! | Kuzgun Leşi - İlkim Baldan Kesgin | Kitap Yorumu
# AlNGKumtsiI
# 2023-04-29
# view_count : 3305
# like_count : 251
#
#
# AYIP ETTİN OLIVIA | Dokunulmazlar   J J Mcavoy Kitap Yorumu
# Kb5gpi5F6J0
# 2023-04-23
# view_count : 2032
# like_count : 145
#
#
# Project Pan 3. Güncelleme MART 2023
# 5YY3c2Qm71Y
# 2023-04-16
# view_count : 4005
# like_count : 253
#
#
# 15 KİTAP! | Mart Ayında Okuduklarım 2023 📚💓
# Z103ReDVmWY
# 2023-04-15
# view_count : 15177
# like_count : 769
#
#
# Güz Esintisi 2 - Burçin Sarıdoğan | Kitap Yorumu 📚😢
# _z_6bdmTW04
# 2023-04-09
# view_count : 2108
# like_count : 193
#
#
# BU KİTAP BENİ TRAVMATİZE ETTİ! | Güz Esintisi 1 - Burçin Sarıdoğan | Kitap Yorumu
# Mfy2HkrRkBw
# 2023-04-08
# view_count : 3036
# like_count : 262
#
#
# Büyük Polisiye Kargosu ve ÇEKİLİŞ  | Gelen Kitap Kargolarını Açıyorum! 📚💓
# 780qsOf9bSw
# 2023-04-01
# view_count : 12135
# like_count : 1104
#
#
# 400 SAYFAYI BİR GÜNDE OKUMAK! | Ötanazi Okulu 3 - Maral Atmaca
# Q91u9mr8GjM
# 2023-03-26
# view_count : 11250
# like_count : 602
#
#
# Gelen Kitap Kargolarını Açıyorum! 💓📚
# tufaQNj7QZY
# 2023-03-25
# view_count : 12547
# like_count : 810
#
#
# Şubat Ayında Okuduklarım, 2023 | En İyi Polisiye Kitaplar, Romantik Gençlik Kitapları...
# D6g0UE2EXnk
# 2023-03-19
# view_count : 18734
# like_count : 820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 11
#       9 video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
#      10 video_stats_response = requests.get(video_stats_url).json()
# ---> 11 time.sleep(3)
#      12 view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
#      13 like_count = video_stats_response['items'][0]["statistics"]["likeCount"]
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 

for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_date = video['snippet']['publishedAt']
        upload_date= str(upload_date).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        #save in pandas df
        df = df._append({
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }, 
        ignore_index = True
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6232\3308869388.py in ?()
#      14         view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
#      15         like_count = video_stats_response['items'][0]["statistics"]["likeCount"]
#      16
#      17         #save in pandas df
# ---> 18         df = df.concat({
#      19             "video_id": video_id,
#      20             "video_title": video_title,
#      21             "upload_date": upload_date,
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'
