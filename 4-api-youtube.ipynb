# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Helpful does:
# - What is API, REST,RESTFULL
# - What is request, response and keys
#
# - Find different apis : https://github.com/public-apis/public-apis
# - https://dev.socrata.com/consumers/getting-started.html
# - Create API key : https://console.cloud.google.com/
# - https://blog.streamlit.io/8-tips-for-securely-using-api-keys/
# - Find youtube Channel Id : https://www.streamweasels.com/tools/youtube-channel-id-and-user-id-convertor/
#
# - Youtube Api docs: https://developers.google.com/youtube/v3/docs?hl=tr
#
# - https://help.openai.com/en/articles/5112595-best-practices-for-api-key-safety
# - https://blog.streamlit.io/8-tips-for-securely-using-api-keys/

# %% [markdown]
# - **Source:**  https://data.colorado.gov

# %%
# url_api_endpoint = "https://data.colorado.gov/resource/tv8u-hswn.json"
url="https://data.colorado.gov/resource/tv8u-hswn.json?$where=age between 20 and 25 and year between 2020 and 2025&county=Boulder&$select=year,age,femalepopulation"

# %%
url = url.replace(" ","%20")

# %%
data = pd.read_json(url)

# %%
data
# Out:
#     year  age  femalepopulation
# 0   2022   22              3296
# 1   2020   20              3830
# 2   2020   21              3647
# 3   2021   24              2194
# 4   2023   23              2716
# 5   2023   21              3778
# 6   2025   22              3486
# 7   2025   25              2329
# 8   2020   22              3290
# 9   2022   21              3647
# 10  2020   25              2173
# 11  2022   24              2314
# 12  2023   25              2318
# 13  2021   25              2244
# 14  2024   22              3367
# 15  2020   23              2610
# 16  2024   21              3890
# 17  2022   23              2645
# 18  2023   22              3242
# 19  2024   23              2658
# 20  2025   21              3779
# 21  2022   20              3881
# 22  2022   25              2224
# 23  2025   24              2271
# 24  2024   24              2324
# 25  2023   20              3999
# 26  2025   23              2789
# 27  2023   24              2258
# 28  2021   20              3732
# 29  2021   22              3201
# 30  2020   24              2268
# 31  2025   20              3806
# 32  2024   20              3881
# 33  2024   25              2257
# 34  2021   23              2677
# 35  2021   21              3681

# %%
import requests

from config import YOUTUBE_API_KEY
import time

# %%
CHANNEL_ID ="UCeT3Ep2sgFiy0B5N1gX5N4Q"
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyCLwXMs17fEnUb4FL5SCZJXY0ittj3LpCk&channelId=UCeT3Ep2sgFiy0B5N1gX5N4Q&part=snippet,id&order=date&maxResults=1000

# %%
response = requests.get(url).json()
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '_r-IV_MJTKCBoPtcoMZ-5b4C844',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'TR',
#  'pageInfo': {'totalResults': 737, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'OH9YDQ2sDbgByOfPPsVhnb6ZTtY',
#    'id': {'kind': 'youtube#video', 'videoId': 've2avkyY5XM'},
#    'snippet': {'publishedAt': '2023-12-31T15:00:52Z',
#     'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#     'title': '2024&#39;te Bunları Yapmak ZORUNDAYIM!',
#     'description': 'Çekilişe katılmak için videoya ulaşın: https://www.youtube.com/watch?v=kZ42YKEPpAc Bana Ulaşmak İçin: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ve2avkyY5XM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ve2avkyY5XM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ve2avkyY5XM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sıla Özkan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-31T15:00:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 
z',
#     'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#     'title': 'ARDEL 2: KAN GÜLLERİ  - Sinem Ataklı | OKUMALISIN!',
#     'description': 'Kitabı İncelemek veya Satın Almak İçin: https://www.ephesusdukkan.com/ardel-2-kan-gulleri-ciltli-imzali Bana Ulaşmak İçin: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Z6qyHbUGjj4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Z6qyHbUGjj4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Z6qyHbUGjj4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sıla Özkan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-20T16:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JngjKl8KFRGPG5pPASR8MK0HsnQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'HqA8fBieOPs'},
#    'snippet': {'publishedAt': '2023-01-13T16:00:08Z',
#     'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#     'title': 'BÖYLE BİR KİTAP OLABİLİR Mİ?! | Ateşpare 2 - Ceren Melek',
#     'description': 'Kitabı İncelemek veya Satın Almak İçin: https://www.ephesusdukkan.com/atespare-2-ciltli Bana Ulaşmak İçin: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HqA8fBieOPs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HqA8fBieOPs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HqA8fBieOPs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sıla Özkan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-13T16:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'h8T4ebBxq3qxwuWSJpzvS8OCLag',
#    'id': {'kind': 'youtube#video', 'videoId': 'hapjfflTMRo'},
#    'snippet': {'publishedAt': '2023-01-06T15:00:21Z',
#     'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#     'title': 'Unutulmuş Kuşlar Göğü - K. Kübra Berk | OKUMALISIN!',
#     'description': 'Kitabı İncelemek veya Satın Almak İçin: https://www.ephesusdukkan.com/unutulmus-kuslar-gogu-1-ciltli-imzali Bana Ulaşmak İçin: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hapjfflTMRo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hapjfflTMRo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hapjfflTMRo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sıla Özkan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-06T15:00:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Z5LzOjlotL3nUSpniUmXCXJ0TBU',
#    'id': {'kind': 'youtube#video', 'videoId': 'fHIoHUwLyIQ'},
#    'snippet': {'publishedAt': '2023-01-01T15:00:14Z',
#     'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#     'title': 'Rengini Yitirmiş Gökkuşağı - Fatih Bayram | Kitap Yorumu |',
#     'description': 'Kitabı Satın Almak İçin: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fHIoHUwLyIQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fHIoHUwLyIQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fHIoHUwLyIQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sıla Özkan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-01T15:00:14Z'}}]}

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'OH9YDQ2sDbgByOfPPsVhnb6ZTtY',
#  'id': {'kind': 'youtube#video', 'videoId': 've2avkyY5XM'},
#  'snippet': {'publishedAt': '2023-12-31T15:00:52Z',
#   'channelId': 'UCeT3Ep2sgFiy0B5N1gX5N4Q',
#   'title': '2024&#39;te Bunları Yapmak ZORUNDAYIM!',
#   'description': 'Çekilişe katılmak için videoya ulaşın: https://www.youtube.com/watch?v=kZ42YKEPpAc Bana Ulaşmak İçin: ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ve2avkyY5XM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/ve2avkyY5XM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/ve2avkyY5XM/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Sıla Özkan',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-12-31T15:00:52Z'}}

# %%
response["items"][0]['id']['videoId']
# Out:
# 've2avkyY5XM'

# %%
response["items"][0]['snippet']['title']
# Out:
# '2024&#39;te Bunları Yapmak ZORUNDAYIM!'

# %%
response["items"][0]['snippet']['description']
# Out:
# 'Çekilişe katılmak için videoya ulaşın: https://www.youtube.com/watch?v=kZ42YKEPpAc Bana Ulaşmak İçin: ...'

# %%
response["items"][0]['snippet']['publishedAt']
# Out:
# '2023-12-31T15:00:52Z'

# %%
video_title = response["items"][0]['snippet']['title']
video_id = response["items"][0]['id']['videoId']
video_description = response["items"][0]['snippet']['description']

upload_time= response["items"][0]['snippet']['publishedAt']
upload_time = str(upload_time).split("T")[0]

print(video_title)
print(video_id)
print(video_description)
print(upload_time)
# Out:
# 2024&#39;te Bunları Yapmak ZORUNDAYIM!
# ve2avkyY5XM
# Çekilişe katılmak için videoya ulaşın: https://www.youtube.com/watch?v=kZ42YKEPpAc Bana Ulaşmak İçin: ...
# 2023-12-31

# %%
# for loop in response
for video in response["items"]:
    if video['id']['kind'] == "youtube#video":
        video_title = video['snippet']['title']
        print(video_title)
# Out:
# 2024&#39;te Bunları Yapmak ZORUNDAYIM!
# Yılın Son Bitenleri! | 2023&#39;te Bitenler, Aralık
# Project Pan 12. Güncelleme FİNAL | ARALIK 2023 💄🫶
# BU KİTAP BENİ DELİRTTİ! | Gökçen - Loressima Kitap Yorumu
# Ephesus&#39;tan Gelen Kitap Kargosunu Açıyoruz!
# Kitaplık Turu, 2023 | Kitaplığımda Hangi Kitaplar Var?
# ÖTANAZİ OKULU 4 - Maral Atmaca | Övdüm mü, Gömdüm mü?
# Ekim Ayında Okuduklarım 2023 | 10 KİTAP!
# Eylül Ayında Okuduklarım 2023 | 10 KİTAP!
# BU HİKAYE NASIL SONRA ERDİ? | Yabancı Elyel - Öznur Yıldırım  Övdüm mü Gömdüm mü?
# Yabancı Veyl - Öznur Yıldırım | Övdüm mü GÖMDÜM mü?
# Project Pan 8. Güncelleme | AĞUSTOS  2023 💄🫶
# 2 AYLIK BİTENLER | Haziran &amp; Temmuz Ayında Bitenler 💄💓
# Temmuz Ayında Okuduklarım 2023 📚💓
# 7 KİTAP! | Haziran Ayında Okuduklarım 2023 📚💓
# 11 KİTAP! | Mayıs Ayında Okuduklarım 2023 📚💓
# BU BİLGİLERİ TÜRKİYE&#39;DE İLK KEZ OKUYACAKSINIZ! | Çırak -Ayhan Özden
# 120 SAYFAYA BİR ÖMÜR SIĞDIRMAK | Perşembe&#39;yi Beklerken - Tolga Kayır
# Korkusuzlar -  J J Mcavoy | Kitap Yorumu
# Kidega’dan 350₺lik Kitap Alışverişi Yaptım 📚🤍
# Project Pan 5. Güncelleme | MAYIS 2023 💄🫶
# Ben Kişisel Gelişim Okuyorum... BEN!?
# Benimle Bir Gün 🎬💅🤍
# Zengin Koca Bulma Sanatı - Ayhan Özden | Övdüm mü, Gömdüm mü?
# Orada Olmayanı Nerede Ararsın? Merdivende değil, Daima Merdiven Boşluğunda. - Şeytanın Ta Kendisi 2
# Project Pan 4. Güncelleme NİSAN  2023
# En Çok İltifat Aldıran Parfüm, Saç Dökülmesine Son | Mart Ayı Bitenler, 2023
# DAHA ÖNCE HİÇ BÖYLE KİTAP OKUMAMIŞTIM! | Kuzgun Leşi - İlkim Baldan Kesgin | Kitap Yorumu
# AYIP ETTİN OLIVIA | Dokunulmazlar   J J Mcavoy Kitap Yorumu
# 15 KİTAP! | Mart Ayında Okuduklarım 2023 📚💓
# Büyük Polisiye Kargosu ve ÇEKİLİŞ  | Gelen Kitap Kargolarını Açıyorum! 📚💓
# 400 SAYFAYI BİR GÜNDE OKUMAK! | Ötanazi Okulu 3 - Maral Atmaca
# Gelen Kitap Kargolarını Açıyorum! 💓📚
# Şubat Ayında Okuduklarım, 2023 | En İyi Polisiye Kitaplar, Romantik Gençlik Kitapları...
# Şubat Ayında Bitenler, 2023 | Gördüğüm en iyi uygun fiyatlı şampuan, imza parfümüm...
# Belladonna’ya Bir Sözüm Var!
# Amazon&#39;dan Kitap Alışverişi Yaptım! | Şubat 2023 📚🫶
# Project Pan 2023, Şubat Güncellemesi 💄💓
# Şubat Ayında Okuduklarım 📚🤍
# Çiçekler ve Yasemin Kitap Yorumu ve Depremle Alakalı Konuşmak İstedim
# Youna Ajandamı Nasıl Kullanıyorum? 🤍
# Ocak Ayında Okuduklarım, 2023
# Ocak Ayında Neler Okudum? 📚🤍
# Bitenler 2023, doğal roll on, yüz jileti, kırk yıllık far paleti
# Rota 2   Leman Veli  | Kitap Yorumu
# Aralık Ayında Okuduklarım, 2022 | Ateşpare 2, Saga, Karmakarışık...
# ARDEL 2: KAN GÜLLERİ  - Sinem Ataklı | OKUMALISIN!
# BÖYLE BİR KİTAP OLABİLİR Mİ?! | Ateşpare 2 - Ceren Melek
# Unutulmuş Kuşlar Göğü - K. Kübra Berk | OKUMALISIN!
# Rengini Yitirmiş Gökkuşağı - Fatih Bayram | Kitap Yorumu |

# %%
video_id='DUI04XwQo4A' # en son videonun idsi
video_ur_endpoint = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
video_response = requests.get(video_ur_endpoint).json()

# %%
video_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'B7VDbSZ4uMRx0B7ejJ2NZ4FM1rE',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'SxO6hQcdLWp6u5JkVTifrlGUJoY',
#    'id': 'DUI04XwQo4A',
#    'statistics': {'viewCount': '6580',
#     'likeCount': '582',
#     'favoriteCount': '0',
#     'commentCount': '106'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
video_response['items'][0]['statistics']
# Out:
# {'viewCount': '6580',
#  'likeCount': '582',
#  'favoriteCount': '0',
#  'commentCount': '106'}

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_time = video['snippet']['publishedAt']
        upload_date= str(upload_time).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()
        #time.sleep(3)
        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        print(video_title)
        print(video_id)
        print(upload_date)
        print(f"view_count : {view_count}")
        print(f"like_count : {like_count}")
        print("\n")
# Out:
# 2024&#39;te Bunları Yapmak ZORUNDAYIM!
# ve2avkyY5XM
# 2023-12-31
# view_count : 5948
# like_count : 457
#
#
# Yılın Son Bitenleri! | 2023&#39;te Bitenler, Aralık
# BNPaebpvym4
# 2023-12-30
# view_count : 2215
# like_count : 186
#
#
# Project Pan 12. Güncelleme FİNAL | ARALIK 2023 💄🫶
# RdRz_kfqngA
# 2023-12-24
# view_count : 3868
# like_count : 303
#
#
# BU KİTAP BENİ DELİRTTİ! | Gökçen - Loressima Kitap Yorumu
# DUI04XwQo4A
# 2023-12-16
# view_count : 6580
# like_count : 582
#
#
# Ephesus&#39;tan Gelen Kitap Kargosunu Açıyoruz!
# SRorNk8TqCs
# 2023-11-26
# view_count : 5123
# like_count : 430
#
#
# Kitaplık Turu, 2023 | Kitaplığımda Hangi Kitaplar Var?
# uFySnEtrOt4
# 2023-11-19
# view_count : 10330
# like_count : 502
#
#
# ÖTANAZİ OKULU 4 - Maral Atmaca | Övdüm mü, Gömdüm mü?
# q6G_DzkGrCQ
# 2023-11-11
# view_count : 4178
# like_count : 269
#
#
# Ekim Ayında Okuduklarım 2023 | 10 KİTAP!
# iVHbUOBEmj0
# 2023-11-05
# view_count : 4632
# like_count : 322
#
#
# Eylül Ayında Okuduklarım 2023 | 10 KİTAP!
# FAKi1Xqhj2w
# 2023-10-22
# view_count : 5462
# like_count : 362
#
#
# BU HİKAYE NASIL SONRA ERDİ? | Yabancı Elyel - Öznur Yıldırım  Övdüm mü Gömdüm mü?
# s_-2UCqFuq4
# 2023-10-07
# view_count : 10976
# like_count : 586
#
#
# Yabancı Veyl - Öznur Yıldırım | Övdüm mü GÖMDÜM mü?
# rGGVz9wr7Gs
# 2023-10-01
# view_count : 4509
# like_count : 324
#
#
# Project Pan 8. Güncelleme | AĞUSTOS  2023 💄🫶
# H0u3Fqg7_Oo
# 2023-09-03
# view_count : 3828
# like_count : 251
#
#
# 2 AYLIK BİTENLER | Haziran &amp; Temmuz Ayında Bitenler 💄💓
# Y3-t8_TyiG0
# 2023-08-27
# view_count : 4160
# like_count : 261
#
#
# Temmuz Ayında Okuduklarım 2023 📚💓
# YCxwn1dUp30
# 2023-08-20
# view_count : 4429
# like_count : 310
#
#
# 7 KİTAP! | Haziran Ayında Okuduklarım 2023 📚💓
# y-5VfonOkpg
# 2023-07-23
# view_count : 8853
# like_count : 528
#
#
# 11 KİTAP! | Mayıs Ayında Okuduklarım 2023 📚💓
# 9xmRjqDcxUk
# 2023-06-25
# view_count : 8656
# like_count : 517
#
#
# BU BİLGİLERİ TÜRKİYE&#39;DE İLK KEZ OKUYACAKSINIZ! | Çırak -Ayhan Özden
# 5RAOBGciIbc
# 2023-06-17
# view_count : 2043
# like_count : 130
#
#
# 120 SAYFAYA BİR ÖMÜR SIĞDIRMAK | Perşembe&#39;yi Beklerken - Tolga Kayır
# O2a2UzX6Jqo
# 2023-06-10
# view_count : 1476
# like_count : 143
#
#
# Korkusuzlar -  J J Mcavoy | Kitap Yorumu
# YbPaO3maL5k
# 2023-06-04
# view_count : 1675
# like_count : 129
#
#
# Kidega’dan 350₺lik Kitap Alışverişi Yaptım 📚🤍
# d0OBljmxZqw
# 2023-05-31
# view_count : 51123
# like_count : 2487
#
#
# Project Pan 5. Güncelleme | MAYIS 2023 💄🫶
# FiTpzc_8WEA
# 2023-05-28
# view_count : 4953
# like_count : 268
#
#
# Ben Kişisel Gelişim Okuyorum... BEN!?
# 0UELIWue_mU
# 2023-05-27
# view_count : 1812
# like_count : 173
#
#
# Benimle Bir Gün 🎬💅🤍
# LNYF5SSkzrE
# 2023-05-24
# view_count : 7764
# like_count : 351
#
#
# Zengin Koca Bulma Sanatı - Ayhan Özden | Övdüm mü, Gömdüm mü?
# dFA1QLQx73Q
# 2023-05-21
# view_count : 5538
# like_count : 403
#
#
# Orada Olmayanı Nerede Ararsın? Merdivende değil, Daima Merdiven Boşluğunda. - Şeytanın Ta Kendisi 2
# tOPbNjpf8nw
# 2023-05-07
# view_count : 2414
# like_count : 170
#
#
# Project Pan 4. Güncelleme NİSAN  2023
# k_-9cCz7vLA
# 2023-05-06
# view_count : 4680
# like_count : 250
#
#
# En Çok İltifat Aldıran Parfüm, Saç Dökülmesine Son | Mart Ayı Bitenler, 2023
# _lGPR9WSioo
# 2023-04-30
# view_count : 4752
# like_count : 263
#
#
# DAHA ÖNCE HİÇ BÖYLE KİTAP OKUMAMIŞTIM! | Kuzgun Leşi - İlkim Baldan Kesgin | Kitap Yorumu
# AlNGKumtsiI
# 2023-04-29
# view_count : 3327
# like_count : 252
#
#
# AYIP ETTİN OLIVIA | Dokunulmazlar   J J Mcavoy Kitap Yorumu
# Kb5gpi5F6J0
# 2023-04-23
# view_count : 2052
# like_count : 145
#
#
# 15 KİTAP! | Mart Ayında Okuduklarım 2023 📚💓
# Z103ReDVmWY
# 2023-04-15
# view_count : 15251
# like_count : 772
#
#
# Büyük Polisiye Kargosu ve ÇEKİLİŞ  | Gelen Kitap Kargolarını Açıyorum! 📚💓
# 780qsOf9bSw
# 2023-04-01
# view_count : 12225
# like_count : 1104
#
#
# 400 SAYFAYI BİR GÜNDE OKUMAK! | Ötanazi Okulu 3 - Maral Atmaca
# Q91u9mr8GjM
# 2023-03-26
# view_count : 11428
# like_count : 612
#
#
# Gelen Kitap Kargolarını Açıyorum! 💓📚
# tufaQNj7QZY
# 2023-03-25
# view_count : 12629
# like_count : 809
#
#
# Şubat Ayında Okuduklarım, 2023 | En İyi Polisiye Kitaplar, Romantik Gençlik Kitapları...
# D6g0UE2EXnk
# 2023-03-19
# view_count : 18929
# like_count : 826
#
#
# Şubat Ayında Bitenler, 2023 | Gördüğüm en iyi uygun fiyatlı şampuan, imza parfümüm...
# AhAnyr6vuFA
# 2023-03-18
# view_count : 3529
# like_count : 218
#
#
# Belladonna’ya Bir Sözüm Var!
# bKZD8O-CzZo
# 2023-03-17
# view_count : 14970
# like_count : 925
#
#
# Amazon&#39;dan Kitap Alışverişi Yaptım! | Şubat 2023 📚🫶
# RIDaPBnmr-I
# 2023-03-11
# view_count : 12672
# like_count : 625
#
#
# Project Pan 2023, Şubat Güncellemesi 💄💓
# Bhrm2MOWKwg
# 2023-03-05
# view_count : 4979
# like_count : 281
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 13
#      11 #time.sleep(3)
#      12 view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
# ---> 13 like_count = video_stats_response['items'][0]["statistics"]["likeCount"]
#      15 print(video_title)
#      16 print(video_id)
#
# KeyError: 'likeCount'

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 

for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_date = video['snippet']['publishedAt']
        upload_date= str(upload_date).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        #save in pandas df
        df = df._append({
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }, 
        ignore_index = True
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"])
#       3 for video in response['items']:
#       4     if video['id']['kind'] == 'youtube#video':
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Creating workflow

# %%
import requests
import pandas as pd
import time
from config import YOUTUBE_API_KEY

# %%
def get_video_statistics(video_id, youtube_api_key):
    # collecting video statistics
    video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+youtube_api_key
    video_stats_response = requests.get(video_stats_url).json()

    view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
    like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

    return view_count, like_count

# %%
def get_videos_from_channel(df, channel_id, youtube_api_key):
    # make API call
    pageToken = ""
    url = "https://www.googleapis.com/youtube/v3/search?key="+youtube_api_key+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=1000"+pageToken
    
    response = requests.get(url).json()
    time.sleep(3)

    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_title = video['snippet']['title']
            video_id = video['id']['videoId']
            upload_date = video['snippet']['publishedAt']
            upload_date= str(upload_date).split("T")[0]

            view_count, like_count = get_video_statistics(video_id, youtube_api_key)

            #save in pandas df
            df = df._append({
                "video_id": video_id,
                "video_title": video_title,
                "upload_date": upload_date,
                "view_count": view_count,
                "like_count": like_count
            }, 
            ignore_index = True
            )
    return df

# %%
CHANNEL_ID = "UCLA_DiR1FfKNvjuUpBHmylQ"

df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 
youtube_data = get_videos_from_channel(df, CHANNEL_ID, YOUTUBE_API_KEY)

# %%
youtube_data.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  lLW6t8z1REI  A New Name and New Journey for an Asteroid Mis...  2023-12-30
# 1  IGuHErKAiHs                       NASA 2024: Onward and Upward  2023-12-27
# 2  _9ke_kfMBbc  Ultra-High-Definition Video Beamed From Deep S...  2023-12-23
# 3  KjCdGqgD9Bs  Rollout of the X-59 Quesst Supersonic Plane (O...  2023-12-22
# 4  jPTD2gnZFUw  Live Video from the International Space Statio...  2023-11-16
#
#   view_count like_count
# 0      45224       1977
# 1     829134      14807
# 2     113628       2494
# 3          0        186
# 4     502883      11041
